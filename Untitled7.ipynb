# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('cleaned_melb_dataset.csv')
print(df.shape)
# Out:
# (10578, 13)

# %%
# Define the columns to remove
# (Includes both the original features and their encoded region variations)
columns_to_remove = [
    "Landsize",
    "Lattitude",  # Spelled with two 't's as seen in the dataset
    "Price_per_landsize",
    "Regionname_Eastern Victoria",
    "Regionname_Northern Victoria",
    "Regionname_Western Victoria",
]

# Drop them from your DataFrame
df = df.drop(columns=columns_to_remove, errors="ignore")

# Print remaining columns to verify
print(df.columns.tolist())
# Out:
# ['Rooms', 'Type', 'Price', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'Longtitude', 'Regionname', 'Price_per_Landsize', 'Distance_Category']

# %%
df.head()
# Out:
#    Rooms Type      Price  Distance  Bedroom2  Bathroom  Car  Longtitude  \
# 0      2    h  1480000.0       2.5       2.0       1.0  1.0    144.9984
# 1      2    h  1035000.0       2.5       2.0       1.0  0.0    144.9934
# 2      3    h  1465000.0       2.5       3.0       2.0  0.0    144.9944
# 3      3    h   850000.0       2.5       3.0       2.0  1.0    144.9969
# 4      2    h   941000.0       2.5       2.0       1.0  0.0    144.9953
#
#               Regionname  Price_per_Landsize Distance_Category
# 0  Northern Metropolitan         7326.732673              Near
# 1  Northern Metropolitan         6634.615385              Near
# 2  Northern Metropolitan        10932.835821              Near
# 3  Northern Metropolitan         9042.553191              Near
# 4  Northern Metropolitan         5198.895028              Near
