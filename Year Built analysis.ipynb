# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel("melb_data.xlsx")
df.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#                   Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0  2016-03-12 00:00:00       2.5      3067  ...         1  1.0       202
# 1  2016-04-02 00:00:00       2.5      3067  ...         1  0.0       156
# 2  2017-04-03 00:00:00       2.5      3067  ...         2  0.0       134
# 3  2017-04-03 00:00:00       2.5      3067  ...         2  1.0        94
# 4  2016-04-06 00:00:00       2.5      3067  ...         1  2.0       120
#
#    BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df = df.dropna(subset=['YearBuilt'])

# %%
import matplotlib.pyplot as plt

plt.scatter(df['YearBuilt'], df['Price'])
plt.xlabel('YearBuilt')
plt.ylabel('Price')
plt.title("Price vs Year Built")
plt.show()
# Does not have any connection

# %%
plt.hist(df['Price'], bins=20)
plt.xlabel("Price")
plt.ylabel("Count")
plt.title("Price vs Year Built")
plt.show()
# Does not have any connection

# %%
plt.scatter(df["YearBuilt"], df["Distance"])
plt.xlabel("YearBuilt")
plt.ylabel("Distance")
plt.title("YearBuilt vs Distance")
plt.show()
# No relationship

# %%
plt.scatter(df["YearBuilt"], df["Rooms"])
plt.xlabel("YearBuilt")
plt.ylabel("Rooms")
plt.title("YearBuilt vs Rooms")
plt.show()
# No relationship

# %%
plt.scatter(df["YearBuilt"], df["Bedroom2"])
plt.xlabel("YearBuilt")
plt.ylabel("Bedroom2")
plt.title("YearBuilt vs Bedroom2")
plt.show()
# No relationship

# %%
plt.scatter(df["YearBuilt"], df["Bathroom"])
plt.xlabel("YearBuilt")
plt.ylabel("Bathroom")
plt.title("YearBuilt vs Bathroom")
plt.show()
# No relationship

# %%
plt.scatter(df["YearBuilt"], df["Car"])
plt.xlabel("YearBuilt")
plt.ylabel("Car")
plt.title("YearBuilt vs Car")
plt.show()

# %%
plt.scatter(df["YearBuilt"], df["Landsize"])
plt.xlabel("YearBuilt")
plt.ylabel("Landsize")
plt.title("YearBuilt vs Landsize")
plt.show()
# No relationship

# %%
plt.scatter(df["YearBuilt"], df["BuildingArea"])
plt.xlabel("YearBuilt")
plt.ylabel("BuildingArea")
plt.title("YearBuilt vs BuildingArea")
plt.show()
# No relationship

# %%
plt.scatter(df["YearBuilt"], df["Propertycount"])
plt.xlabel("YearBuilt")
plt.ylabel("Propertycount")
plt.title("YearBuilt vs Propertycount")
plt.show()
# No relationship

# %%
plt.scatter(df["YearBuilt"], df["Lattitude"])
plt.xlabel("YearBuilt")
plt.ylabel("Lattitude")
plt.title("YearBuilt vs Lattitude")
plt.show()

# %%
plt.scatter(df["YearBuilt"], df["Longtitude"])
plt.xlabel("YearBuilt")
plt.ylabel("Longtitude")
plt.title("YearBuilt vs Longtitude")
plt.show()

# %%
# Therfore, we come to the conclusion that there is no relationship between yearbuilt and any of the other variables.
