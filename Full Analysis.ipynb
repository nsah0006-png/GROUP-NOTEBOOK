# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('melb_data.xlsx')
print(df.shape)
# Out:
# (13580, 21)

# %%
# missing values per column
missing_counts = df.isnull().sum()

# precentage of missing values
missing_percentages = (df.isnull().sum() / len(df)) * 100

# Table of missing count and percentage
missing_summary = pd.DataFrame(
    {'Missing Count': missing_counts,
    'Percentage (%)': missing_percentages})

# shows the varibles that has missing values in decending order
final_report = missing_summary[missing_summary['Missing Count'] > 0].sort_values(by='Missing Count', ascending=False)

print(final_report)
# Out:
#               Missing Count  Percentage (%)
# BuildingArea           6450       47.496318
# YearBuilt              5375       39.580265
# CouncilArea            1369       10.081001
# Car                      62        0.456554

# %%
df['Car'] = df['Car'].fillna(0)

# remove duplicated rows
df = df.drop_duplicates()

# Fix the Date data type mismatch so it plots chronologically
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y', errors='coerce')

# %%
print("Check")
print("Number of properties with 0 Landsize left:", (df['Landsize'] == 0).sum())
print("Number of properties with 0 Building area left:", (df['BuildingArea'] == 0).sum())
print("Number of missing values left in Car column:", df['Car'].isnull().sum())
print("Total rows remaining in cleaned dataset:", len(df))
# Out:
# Check
# Number of properties with 0 Landsize left: 1939
# Number of properties with 0 Building area left: 17
# Number of missing values left in Car column: 0
# Total rows remaining in cleaned dataset: 13580

# %%
corr = df.corr(numeric_only=True)

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
plt.figure(figsize=(10, 8))

# Pass the mask into the heatmap function
sns.heatmap(corr, mask=mask, annot=True, cmap="coolwarm", fmt=".2f", square=True)

plt.title("Correlation Matrix of Housing Variables")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of Housing Variables')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, x= "CouncilArea", y="Price", hue = "CouncilArea")
plt.title("CouncilArea vs Price")
# No correlation
# Out:
# Text(0.5, 1.0, 'CouncilArea vs Price')

# %%
plt.hist(df["Price"], bins=20)
plt.xlabel("Price")
plt.ylabel("CouncilArea")
plt.title("CouncilArea vs Price")
plt.show()

# %%
sns.boxplot(data = df, x="CouncilArea", y="Price")
plt.title("CouncilArea vs Price")
# Out:
# Text(0.5, 1.0, 'CouncilArea vs Price')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, x= "YearBuilt", y="Price", hue = "YearBuilt")
plt.title("YearBuilt vs Price")
# No correlation
# Out:
# Text(0.5, 1.0, 'YearBuilt vs Price')

# %%
plt.hist(df["Price"], bins=20)
plt.xlabel("Price")
plt.ylabel("YearBuilt")
plt.title("YearBuilt vs Price")
plt.show()

# %%
sns.boxplot(data = df, x="YearBuilt", y="Price")
plt.title("YearBuilt vs Price")
# Out:
# Text(0.5, 1.0, 'YearBuilt vs Price')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, x= "Landsize", y="Price", hue = "Landsize")
plt.title("Landsize vs Price")
# No correlation
# Out:
# Text(0.5, 1.0, 'Landsize vs Price')

# %%
plt.hist(df["Price"], bins=20)
plt.xlabel("Price")
plt.ylabel("Landsize")
plt.title("Landsize vs Price")
plt.show()

# %%
sns.boxplot(data = df, x="Landsize", y="Price")
plt.title("Landsize vs Price")
# Out:
# Text(0.5, 1.0, 'Landsize vs Price')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, x= "Distance", y="Price", hue = "Distance")
plt.title("Distance vs Price")
#This chart visually proves that increasing distance from the CBD guarantees a more affordable market landscape.
# Out:
# Text(0.5, 1.0, 'Distance vs Price')

# %%
plt.hist(df["Price"], bins=20)
plt.xlabel("Price")
plt.ylabel("Distance")
plt.title("Distance vs Price")
plt.show()

# %%
sns.boxplot(data = df, x="Distance", y="Price")
plt.title("Distance vs Price")
# Out:
# Text(0.5, 1.0, 'Distance vs Price')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, x= "Propertycount", y="Price", hue = "Propertycount")
plt.title("Propertycount vs Price")
#This chart shows that high-volume suburbs offer a more predictable environment for buyers on a budget.
# Out:
# Text(0.5, 1.0, 'Propertycount vs Price')

# %%
plt.hist(df["Price"], bins=20)
plt.xlabel("Price")
plt.ylabel("Propertycount")
plt.title("Propertycount vs Price")
plt.show()

# %%
sns.boxplot(data = df, x="Propertycount", y="Price")
plt.title("Propertycount vs Price")
# Out:
# Text(0.5, 1.0, 'Propertycount vs Price')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, x= "Bedroom2", y="Price", hue = "Bedroom2")
plt.title("Bedroom2 vs Price")
#No correlation
# Out:
# Text(0.5, 1.0, 'Bedroom2 vs Price')

# %%
plt.hist(df["Price"], bins=20)
plt.xlabel("Price")
plt.ylabel("Bedroom2")
plt.title("Bedroom2 vs Price")
plt.show()

# %%
sns.boxplot(data = df, x="Bedroom2", y="Price")
plt.title("Bedroom2 vs Price")
# Out:
# Text(0.5, 1.0, 'Bedroom2 vs Price')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, x= "Suburb", y="Price", hue = "Suburb")
plt.title("Suburb vs Price")
# Out:
# Text(0.5, 1.0, 'Suburb vs Price')

# %%
plt.hist(df["Price"], bins=20)
plt.xlabel("Price")
plt.ylabel("Suburb")
plt.title("Suburb vs Price")
plt.show()

# %%
sns.boxplot(data = df, x="Suburb", y="Price")
plt.title("Suburb vs Price")
# Out:
# Text(0.5, 1.0, 'Suburb vs Price')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, x= "Longtitude", y="Price", hue = "Longtitude")
plt.title("Longtitude vs Price")
# Out:
# Text(0.5, 1.0, 'Longtitude vs Price')

# %%
plt.hist(df["Price"], bins=20)
plt.xlabel("Price")
plt.ylabel("Longtitude")
plt.title("Longtitude vs Price")
plt.show()

# %%
sns.boxplot(data = df, x="Longtitude", y="Price")
plt.title("Longtitude vs Price")
# Out:
# Text(0.5, 1.0, 'Longtitude vs Price')

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df, x= "Lattitude", y="Price", hue = "Lattitude")
plt.title("Lattitude vs Price")
# Out:
# Text(0.5, 1.0, 'Lattitude vs Price')

# %%
plt.hist(df["Price"], bins=20)
plt.xlabel("Price")
plt.ylabel("Lattitude")
plt.title("Lattitude vs Price")
plt.show()

# %%
sns.boxplot(data = df, x="Lattitude", y="Price")
plt.title("Lattitude vs Price")
